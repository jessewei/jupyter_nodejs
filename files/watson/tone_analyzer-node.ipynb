// %%
var watson = require('watson-developer-cloud');
// Out:
// undefined

// %%
var tone_analyzer = watson.tone_analyzer({
  username: 'aa3878bc-aefa-4b5b-971c-a92fbf9c606e',
  password: 'o7VsZkJOk4kw',
  version: 'v3',
  version_date: '2016-02-11'
});
// Out:
// undefined
// {
//   "document_tone": {
//     "tone_categories": [
//       {
//         "tones": [
//           {
//             "score": 0.371059,
//             "tone_id": "anger",
//             "tone_name": "Anger"
//           },
//           {
//             "score": 0.245303,
//             "tone_id": "disgust",
//             "tone_name": "Disgust"
//           },
//           {
//             "score": 0.248368,
//             "tone_id": "fear",
//             "tone_name": "Fear"
//           },
//           {
//             "score": 0.052157,
//             "tone_id": "joy",
//             "tone_name": "Joy"
//           },
//           {
//             "score": 0.535403,
//             "tone_id": "sadness",
//             "tone_name": "Sadness"
//           }
//         ],
//         "category_id": "emotion_tone",
//         "category_name": "Emotion Tone"
//       },
//       {
//         "tones": [
//           {
//             "score": 0,
// ...

// %%
tone_analyzer.tone({ text: 'A word is dead when it is said, some say. Emily Dickinson' },
  function(err, tone) {
    if (err)
      console.log(err);
    else
      console.log(JSON.stringify(tone, null, 2));
});
// Out:
// { domain: null,
//   _events: { error: [Function], complete: [Function], pipe: [Function] },
//   _maxListeners: undefined,
//   version_date: '2016-02-11',
//   headers:
//    { accept: 'application/json',
//      'content-type': 'text/plain',
//      'User-Agent': 'watson-developer-cloud-nodejs-1.9.4',
//      Authorization: 'Basic YWEzODc4YmMtYWVmYS00YjViLTk3MWMtYTkyZmJmOWM2MDZlOm83VnNaa0pPazRrdw==',
//      host: 'gateway.watsonplatform.net',
//      'accept-encoding': 'gzip, deflate',
//      'content-length': 57 },
//   method: 'POST',
//   body: 'A word is dead when it is said, some say. Emily Dickinson',
//   useQuerystring: true,
//   gzip: true,
//   callback: [Function],
//   readable: true,
//   writable: true,
//   explicitMethod: true,
//   _qs:
//    { request: [Circular],
//      lib:
//       { unescapeBuffer: [Function],
//         unescape: [Function],
//         escape: [Function],
//         encode: [Function],
//         stringify: [Function],
// ...
